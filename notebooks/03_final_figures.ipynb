# %% [markdown]
# # Final figures
#
# Open the generated metrics tables and figures.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
main = pd.read_csv(root / 'outputs' / 'final' / 'main_metrics.csv')
main
