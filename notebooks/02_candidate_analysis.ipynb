# %% [markdown]
# # Candidate analysis
#
# Look at candidate diversity and score distributions for the executed fallback run.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
frame = pd.read_parquet(root / 'artifacts' / 'scores' / 'merged' / 'val_tune' / 'beam_8.parquet')
frame[['candidate_strategy', 'token_logprob_avg', 'summac_style_score', 'factcc_style_score', 'entity_support_score']].head()
