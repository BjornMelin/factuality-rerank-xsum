# %% [markdown]
# # Sanity checks
#
# Inspect the prepared dataset fixture, candidate schema, and environment report.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
env = pd.read_json(root / 'artifacts' / 'env' / 'env_report.json', typ='series')
dataset = pd.read_parquet(root / 'artifacts' / 'data' / 'dataset.parquet')
env, dataset.head()
