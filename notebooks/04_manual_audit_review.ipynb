# %% [markdown]
# # Manual audit review
#
# Review the manual audit CSV and summary JSON generated by the pipeline.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
audit = pd.read_csv(root / 'outputs' / 'final' / 'manual_audit.csv')
audit.head()
